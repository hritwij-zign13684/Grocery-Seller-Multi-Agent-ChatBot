# %%
from supervisor_agent_4 import supervisor_agent

config = {"configurable": {"thread_id": "aip232"}}
# r1 = supervisor_agent.invoke({'messages':"Hi"},config = config)
# r1

def gen(prompt):
    response = supervisor_agent.invoke({'messages':prompt}, config=config)
    print(response);print()

    print(response['messages'][-1].content)

# %%
"""You are a multi-agent system that is designed to assist users in a grocery shopping scenario. 
Your goal is to provide accurate and helpful responses to user queries while coordinating with other 
agents in the system. You will be interacting with two other agents: the Product Recommendation Agent, 
the Order Processing Agent, and the Support Agent. Each agent has its own specific role and expertise. 
Your task is to determine which agent should handle the user's request based on the content of the 
conversation."""

"""  
    - Additional Parameter for all tools:
        - request (str): A short request explaining the user's need to Product Recommendatio tool"""
# Out:
# "  \n    - Additional Parameter for all tools:\n        - request (str): A short request explaining the user's need to Product Recommendatio tool"

# %%
r2 = supervisor_agent.invoke({'messages':"My name is Optimus"}, config=config)
r3 = supervisor_agent.invoke({'messages':"Do you remember my name?"}, config=config)
r3

# %%
gen("Hi")

# {'messages': [
#     HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='f0873b9b-ff81-4a94-a364-2984ece5827e'), 
#     AIMessage(content="Hello there! Welcome to our grocery shopping assistant. I'm here to help you find and order groceries with ease. \n\nWould you like to:\n1. Browse products by category\n2. Search for specific items\n3. Check out our current deals\n4. Get help with an existing order\n\nWhat can I assist you with today? Feel free to let me know your preferences, and I'll be happy to guide you through our product selection and ordering process.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'c8f6bd96-010c-4eed-b090-16e94d944819', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 11:52:50 GMT', 'content-type': 'application/json', 'content-length': '614', 'connection': 'keep-alive', 'x-amzn-requestid': 'c8f6bd96-010c-4eed-b090-16e94d944819'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [3055]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-48998427-a71d-4687-ba61-3766757d5798-0', usage_metadata={'input_tokens': 1460, 'output_tokens': 99, 'total_tokens': 1559})
#     ]}
# Out:
# {'messages': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='f0f6245d-0eb2-4316-85ca-d7c61ce9da15'), AIMessage(content="Hello there! Welcome to our grocery shopping assistant. I'm here to help you find and order groceries with ease. \n\nWould you like to:\n1. Browse products by category\n2. Search for specific items\n3. Check out our current deals\n4. Get help with an existing order\n\nWhat can I assist you with today? Feel free to let me know your preferences, and I'll be happy to guide you through our product selection and ordering process.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '78e524f4-2449-4dcf-9df0-873878a99883', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:00:40 GMT', 'content-type': 'application/json', 'content-length': '614', 'connection': 'keep-alive', 'x-amzn-requestid': '78e524f4-2449-4dcf-9df0-873878a99883'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [2
# ...

# %%
# from Seperate_Agents.product_rec_agent import product_recommendation_agent

# def gen_2(prompt):
#     response = product_recommendation_agent.invoke({'messages':prompt}, config=config)
#     print(response);print()

#     print(response['messages'][-1].content)

# gen_2("show me some products")

# %%
# gen("Tell me everything about yourself")

# %%
gen("show me what products do you have")

# {'messages': [
#     HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='f0873b9b-ff81-4a94-a364-2984ece5827e'), 
#     AIMessage(content="Hello there! Welcome to our grocery shopping assistant. I'm here to help you find and order groceries with ease. \n\nWould you like to:\n1. Browse products by category\n2. Search for specific items\n3. Check out our current deals\n4. Get help with an existing order\n\nWhat can I assist you with today? Feel free to let me know your preferences, and I'll be happy to guide you through our product selection and ordering process.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'c8f6bd96-010c-4eed-b090-16e94d944819', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 11:52:50 GMT', 'content-type': 'application/json', 'content-length': '614', 'connection': 'keep-alive', 'x-amzn-requestid': 'c8f6bd96-010c-4eed-b090-16e94d944819'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [3055]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-48998427-a71d-4687-ba61-3766757d5798-0', usage_metadata={'input_tokens': 1460, 'output_tokens': 99, 'total_tokens': 1559}), 
#     HumanMessage(content='show me what products do you have', additional_kwargs={}, response_metadata={}, id='3ef2b3fe-c71c-4ba0-bb5d-d9932a22d9f2'), 
#     AIMessage(content=[{'type': 'text', 'text': "I'll help you explore our product catalog. I'll use the Product Recommendation Agent to retrieve a list of available products across different categories."}, {'type': 'tool_use', 'name': 'product_recommendation_agent', 'input': {'request': 'Show available product categories and sample products'}, 'id': 'tooluse_BPc9EevxR-az_bt4Ek0Z2g'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '2f291b17-50e8-4cac-9cfc-52c0fd4fb524', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 11:56:07 GMT', 'content-type': 'application/json', 'content-length': '513', 'connection': 'keep-alive', 'x-amzn-requestid': '2f291b17-50e8-4cac-9cfc-52c0fd4fb524'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [2226]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-e0de9841-217a-4b2a-84bd-c8265d971c78-0', tool_calls=[{'name': 'product_recommendation_agent', 'args': {'request': 'Show available product categories and sample products'}, 'id': 'tooluse_BPc9EevxR-az_bt4Ek0Z2g', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1569, 'output_tokens': 90, 'total_tokens': 1659})], 'is_last_step': False, 'remaining_steps': 23}


# ChatBot core product recommendation agent:
# {'messages': [
#     HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='f0f6245d-0eb2-4316-85ca-d7c61ce9da15'), 
#     AIMessage(content="Hello there! Welcome to our grocery shopping assistant. I'm here to help you find and order groceries with ease. \n\nWould you like to:\n1. Browse products by category\n2. Search for specific items\n3. Check out our current deals\n4. Get help with an existing order\n\nWhat can I assist you with today? Feel free to let me know your preferences, and I'll be happy to guide you through our product selection and ordering process.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '78e524f4-2449-4dcf-9df0-873878a99883', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:00:40 GMT', 'content-type': 'application/json', 'content-length': '614', 'connection': 'keep-alive', 'x-amzn-requestid': '78e524f4-2449-4dcf-9df0-873878a99883'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [2638]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-3f14c31a-0e7f-44a3-86cb-ad1c8de33e00-0', usage_metadata={'input_tokens': 1460, 'output_tokens': 99, 'total_tokens': 1559}), 
#     HumanMessage(content='show me what products do you have', additional_kwargs={}, response_metadata={}, id='20cd61e4-7837-4d2e-8652-ccea413a0b7d'), 
#     HumanMessage(content="{'request': 'Show available product categories and sample products'}", additional_kwargs={}, response_metadata={}, name='SUPERVISOR', id='run-9922daee-cf81-45e1-937d-2a73463f38c7-0')]}


# {'messages': [
#     HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='f0f6245d-0eb2-4316-85ca-d7c61ce9da15'), 
#     AIMessage(content="Hello there! Welcome to our grocery shopping assistant. I'm here to help you find and order groceries with ease. \n\nWould you like to:\n1. Browse products by category\n2. Search for specific items\n3. Check out our current deals\n4. Get help with an existing order\n\nWhat can I assist you with today? Feel free to let me know your preferences, and I'll be happy to guide you through our product selection and ordering process.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '78e524f4-2449-4dcf-9df0-873878a99883', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:00:40 GMT', 'content-type': 'application/json', 'content-length': '614', 'connection': 'keep-alive', 'x-amzn-requestid': '78e524f4-2449-4dcf-9df0-873878a99883'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [2638]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-3f14c31a-0e7f-44a3-86cb-ad1c8de33e00-0', usage_metadata={'input_tokens': 1460, 'output_tokens': 99, 'total_tokens': 1559}), 
#     HumanMessage(content='show me what products do you have', additional_kwargs={}, response_metadata={}, id='20cd61e4-7837-4d2e-8652-ccea413a0b7d'), 
#     HumanMessage(content="{'request': 'Show available product categories and sample products'}", additional_kwargs={}, response_metadata={}, name='SUPERVISOR', id='run-9922daee-cf81-45e1-937d-2a73463f38c7-0'), 
#     AIMessage(content=[{'type': 'text', 'text': "I'll help you explore our product categories and show you some sample products. I'll use the explore_options tool to give you a diverse view of our inventory."}, {'type': 'tool_use', 'name': 'explore_options', 'input': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Organic', 'Meat & Seafood']}, 'id': 'tooluse_n2lGpGQ0SlG_z7cWkU0dmw'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'd04ed2a5-bc85-4613-acbf-879e2cfca991', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:01:21 GMT', 'content-type': 'application/json', 'content-length': '538', 'connection': 'keep-alive', 'x-amzn-requestid': 'd04ed2a5-bc85-4613-acbf-879e2cfca991'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [3717]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, id='run-8edd5de1-62ae-4a62-a5a6-22867544baf6-0', tool_calls=[{'name': 'explore_options', 'args': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Organic', 'Meat & Seafood']}, 'id': 'tooluse_n2lGpGQ0SlG_z7cWkU0dmw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2063, 'output_tokens': 125, 'total_tokens': 2188}), 
    # ToolMessage(content='[{"Sub Category":"Bakery & Desserts","Price":89.99,"Discount":"No Discount","Rating":"Rated 3 out of 5 stars based on 5 reviews.","Title":"Tootie Pie 11\\" Heavenly Chocolate Pie, 2- pack ","Feature":"Two   11\\" Heavenly Chocolate Pie   1 Pie Serves Approximately 8-10 People   Each Pie is Diameter: 11\\" Each and Weight:   3.5 lbs.   Ships with Dry Ice to Maintain Quality & Freshness   Made in the USA","Product Description":"Only for the truly serious chocolate lover, Tootie\\u2019s Heavenly Chocolate Pie is a gooey, fudgy, decadent slice of heaven! With layers of rich, chocolatey filling, surrounded by our handcrafted, flaky crust, it\\u2019s truly a small slice of heaven.\\nSome of our products may contain nuts. Our facility is NOT a n
d Diameter, 3 1\\/2\\u201d High\\nTop Tier: 7\\u201d Diameter, 3 1\\/2\\u201d High\\nServes 16-22\\nEach Cake Arrives With It\\u2019s Own Cake Care Card\\nAllergens: Contains Wheat, Milk, Soy, Egg\\nShips Frozen","ProductID":12,"Seller Pincode":500001},{"Sub Category":"Bakery & Desserts","Price":59.99,"Discount":"No Discount","Rating":"Rated 4.4 out of 5 stars based on 369 reviews.","Title":"David\'s Cookies Mango & Strawberry Cheesecake 2-count (28 Slices Total)","Feature":"2-count\\nStrawberry Cheesecake\\nMango Cheesecake\\nKosher OU-D certified","Product Description":"Strawberry Cheesecake: There\'s only one way to make our cheesecakes taste even better - add fruit! We\'ve topped off our plain New York cheesecake with a generous helping of strawberry preserves for a taste that\'s to die for. Each slice is packed with loads of creamy filling, graham crust and sweet strawberries.Mango Cheesecake: We\'ve done it again with our Mango Cheesecake. It\'s a 10\\" cake with swirls of mango on top of a creamy cheesecake and delicious crust. This mix of cream cheese, and mango will take you on a tropical journey of satisfaction!Includes:2-pack Includes: 1 Strawberry Cheesecake and 1 Mango CheesecakeKosher OU-D certifiedEach cheesecake serves approximately 14 people28 slices total Diameter: 10\\" eachWeight: Approximately 4 lbs. eachShips in Cooler with Dry Ice to Maintain Quality & FreshnessMade in the USASome of our products may contain nuts. Our facility is NOT a nut-free facility, and as a result it is possible that any product may have come in contact with nut or nut oilsImportant Handling Instructions: If not being consumed immediately upon arrival, cakes should be placed in freezer. Allow two hours for cakes to thaw prior to serving. The dessert will arrive at least partially frozen and can be refrozen in its original packaging for up to 6 months or stored in a refrigerator for at least 2 to 3 days.","ProductID":6,"Seller Pincode":700001},{"Sub Category":"Bakery & Desserts","Price":72.99,"Discount":"No Discount","Rating":"Rated 4.3 out of 5 stars based on 87 reviews.","Title":"Ferrara\'s Bakery 4 lbs. Italian Cookie Pack","Feature":"4 lbs. Italian Cookies\\n7 Types of Cookies","Product Description":"Ferrara\\u2019s delicate & buttery cookies are the perfect companion with a cup of coffee. Using secret Old World recipes that are over 100 years old, Ferrara bakes perfect rainbow (tricolori), pignoli (almond-flavored cookies studded with pine nuts), fudge-swirled cookies & more.\\nA little history about the world famous Ferarra bakery. Since 1892 when our great grandfather, Enrico Scoppa and our great grand-uncle, Antonio Ferrara, opera impresario and showman, opened a cafe called Caf\\u00e9 A. Ferrara in Little Italy section in New York City we have prided ourselves on creating superb Italian specialties\\nWe take the extra step of baking two, three and sometimes four times a day, in small batches. Because of the frequency with which we bake, Ferrara acquired our great reputation for quality and freshness. Today, Ferrara is still a family owned business operated by the fifth generation. \\u0422hat\\u2019s perhaps the most wonderful thing about Ferrara. Since its beginning in 1892, the spirit, recipes and devotion to quality has changed very little.\\nIncludes:   Rainbow Tricolori Cookies\\nFudge-swirled Cookies\\nPignoli Cookies\\nCoconut Cookies\\nPlan Sandwich Cookies\\nHalf Moon Cookies\\nTorrincino Cookies   PRODUCED IN A FACILITY WHERE NUTS, MILK, EGGS, SOY & FLOUR ARE PRESENT","ProductID":25,"Seller Pincode":500001},{"Sub Category":"Beverages & Water","Price":18.99,"Discount":"No Discount","Rating":null,"Title":"Gatorade Zero Thirst Quencher, Variety Pack, 12 fl oz, 28-count","Feature":"0 Calories   0g Sugars   0g Saturated Fat","Product Description":"12 - Orange8 - Grape8 - Glacier Freeze28 total bottlesZero sugar","ProductID":102,"Seller Pincode":400050},{"Sub Category":"Beverages & Water","Price":15.99,"Discount":"No Discount","Rating":null,"Title":"Jumex Nectar, Strawberry-Banana, 16 fl oz, 12-Count","Feature":"Strawberry-Banana Nectar   Made from fruit concentrate   16 fl oz can, 12 count   Product of Mexico","Product Description":"Jumex Strawberry BananaNectar\\nAluminum can with resealable top\\n12-count\\nKeep Refrigerated After Opening","ProductID":158,"Seller Pincode":110025},{"Sub Category":"Beverages & Water","Price":15.99,"Discount":"No Discount","Rating":null,"Title":"Capri Sun, 100% Juice, Variety Pack, 6 fl oz, 40-Count","Feature":"Made From Concentrate   No Artificial Colors   No Preservatives   No Added Sugar   40-count","Product Description":"Capri Sun 100% Juice Naturally Flavored Variety Pack delivers refreshing hydration with all natural ingredients\\nVariety pack: 20-Fruit Punch, 10-Berry, and 10-Apple\\nMade with no high fructose corn syrup\\nEach juice pouch for kids contains 3\\/4 cup of fruit juice\\n6 fl oz pouch   Capri Sun 100% Juice Naturally Flavored Variety Pack offers a refreshing on-the-go drink that\'s made with all natural fruit juices. Ready to drink right from the pouch, kids love our naturally flavored fruit juice pouches that capture the ripe, juicy flavor of fresh fruits. This 40 count variety pack box contains 20 Fruit Punch, 10 Berry and 10 Apple pouches for classic flavors your kids know. Each 6 fluid ounce drink pouch contains 3\\/4 cup of fruit juice, so all you get is the taste of real fruit (as part of a well-balanced diet, eat a variety of fruit every day and be sure to make most of your fruits whole fruits; USDA MyPlate recommends a daily intake of 2 cups of fruit for a 2,000 calorie diet). Each of these juice pouches is made with no added sugar and without artificial colors, flavors, preservatives or high fructose corn syrup (not a low calorie food; see nutrition information for calorie and sugar content). Stock up your fridge with a 40 count pack of juice pouches for a quick refreshment around the house and drinks for school lunches.","ProductID":136,"Seller Pincode":700001},{"Sub Category":"Beverages & Water","Price":21.99,"Discount":"No Discount","Rating":null,"Title":"Ito En Jasmine Green Tea, Unsweetened, 16.9 fl oz, 12-count","Feature":"Unsweetened   Refrigerate After Opening   Non GMO   16.9 oz Bottle   12-count","Product Description":"Jasmine Green TeaUnsweetened16.9 oz bottle12-count","ProductID":96,"Seller Pincode":500001},{"Sub Category":"Beverages & Water","Price":23.99,"Discount":"No Discount","Rating":null,"Title":"Big Train, Spiced Chai Tea Latte Drink Mix, 3.5 lbs","Feature":"Spiced Chai Tea Latte Drink Mix   Kosher   Blended, Iced or Hot   Naturally and Artificially Flavored   3.5 lb. Bag","Product Description":"Sip into simple satisfaction","ProductID":148,"Seller Pincode":411005},{"Sub Category":"Snacks","Price":49.99,"Discount":"No Discount","Rating":null,"Title":"Ruffles Potato Chips, Cheddar & Sour Cream, 1.5 oz, 64-count","Feature":"0g Trans Fat Per Serving   Gluten Free   Made with Real Cheddar   Net Weight 96 oz","Product Description":"Ruffles Potato ChipsCheddar & Sour Cream1.5 oz bag64-count","ProductID":1651,"Seller Pincode":411005},{"Sub Category":"Snacks","Price":13.79,"Discount":"No Discount","Rating":null,"Title":"Nonni\\u2019s Biscotti, Almond Dark Chocolate, 25-count","Feature":"Kosher   Roasted Almonds   Individually Wrapped   Premium chocolate (55% Cocoa)   25-Count","Product Description":"Biscotti\\nAlmond Dark Chocolate\\nAlmond biscotti dipped in gourmet chocolate\\nPerfect with a mocha, latte or even a glass of milk","ProductID":1637,"Seller Pincode":700001},{"Sub Category":"Snacks","Price":23.99,"Discount":"No Discount","Rating":null,"Title":"Frito Lay Classic Mix, 1 oz, Variety Pack, 54-count","Feature":"Classic Mix   Variety Pack   54-count   Mix of Favorite Brands And Snacks   Convenient And Compact Box","Product Description":"Product Assortment:   12-Cheetos Crunchy Cheese Flavored Snacks (1 oz)\\n4-Ruffles Cheddar & Sour Cream Flavored Potato Chips (1 oz)\\n4-Lay\'s Barbecue Flavored Potato Chips (1 oz)\\n7-Fritos Original Corn Chips (1 oz)\\n8-Lay\'s Classic Potato Chips (1 oz)\\n7-Doritos Cool Ranch Flavored Tortilla Chips (1 oz)\\n12-Doritos Nacho Cheese Flavored Tortilla Chips (1 oz)","ProductID":1484,"Seller Pincode":110025},{"Sub Category":"Snacks","Price":10.99,"Discount":"No Discount","Rating":null,"Title":"Sugar Bowl, Bakery Duet Bites, 32 oz","Feature":"Kosher   No Preservatives   Individually Wrapped   Made in the USA   Net Weight: 2 lbs","Product Description":"Madeleine & Brownie\\nEvery Bite is Just Right!","ProductID":1625,"Seller Pincode":400050},{"Sub Category":"Snacks","Price":12.49,"Discount":"No Discount","Rating":null,"Title":"Ritz Crackers, 61.65 oz, 18 count","Feature":"Kosher   Crackers   Original   18-Count   Total Net Weight: 61.65 oz","Product Description":"Classic cracker goodness in convenient on-the-go stacks\\nPerfect for pairing with meats, cheeses and more","ProductID":1700,"Seller Pincode":700001},{"Sub Category":"Organic","Price":44.99,"Discount":"No Discount","Rating":"Rated 4.7 out of 5 stars based on 2525 reviews.","Title":"Ruta Maya Organic Medium Roast Whole Bean Coffee 5 lb","Feature":"5 lbs of Organic Whole Bean Coffee   Medium Roast","Product Description":"Mellow yet full-bodied roast. Mild acidity with smooth flavor and a soft finish. Shade-grown 100% Arabica beans, certified USDA organic by the Texas Department of Agriculture. Cultivated by a cooperative of Maya Indian farmers in the Highlands of Chiapas, Mexico.Features:5 lb. bagWhole bean Medium Roast Coffee Certified Organic 100% Arabica, shade grown beansFrom the highlands of Chiapas, Mexico","ProductID":1130,"Seller Pincode":400050},{"Sub Category":"Organic","Price":9.99,"Discount":"No Discount","Rating":null,"Title":"S&W, Organic Black Beans, 15 oz, 8-Count","Feature":"Premium Black Beans   USDA Organic   Non-BPA Can Lining   8-Count   Net Weight 120 oz.","Product Description":"15 oz. can","ProductID":1142,"Seller Pincode":400050},{"Sub Category":"Organic","Price":11.69,"Discount":"No Discount","Rating":null,"Title":"Oregon Chai, Original Organic Chai Tea Latte Concentrate, 32 fl. oz., 3-Count","Feature":"Chai Tea Latte Concentrate   USDA Organic   Just Add Milk   Enjoy Hot   Enjoy Cold","Product Description":"Original Blend of Premium Black Tea, Vanilla, Chai Spices and Honey\\n32 fl oz cartons\\n3 count\\nNet Weight: 3 qt","ProductID":1134,"Seller Pincode":302001},{"Sub Category":"Organic","Price":48.99,"Discount":"No Discount","Rating":null,"Title":"Newman\'s Own Organics Coffee Special Blend K-Cup Pod, 100-count","Feature":"100 K-Cup\\u00ae Pods   Hearty, Full Bodied, Medium Roast, Caffeinated Coffee   USDA Organic Coffee   Compatible with Most K-Cup\\u00ae Pod Single-Serve Coffee Makers","Product Description":"Limit 5 per Member.Item may be available in your local warehouse for a lower, non-delivered price.   Our \\u201c100% of Profits to Charity\\u201d commitment is one of two founding values upon which Newman\\u2019s Own is built. It\\u2019s a very important part of our story, it\\u2019s in our DNA, it\\u2019s why we exist, it motivates all of us, and it\\u2019s the true heart of Newman\\u2019s Own. Great tasting coffee that happens to be organic! Our Fair Trade organic coffee makes a real difference in the lives of coffee farmers around the world. 100% profits to charity. Whether it\'s your morning cup of organic coffee or tea, Newman\'s Own Organics delivers. This Newman\'s Own Organics Special Blend is an inspired blend of medium-roasted Central American coffees and darker-roasted Indonesians is rich and robust, with ample body to stand up to all the cream and sugar that you might want to add to the party. 100 K-Cup\\u00ae podsOrganic Special Blend CoffeeExtra bold, medium roast100% Arabica beans Fair Trade certified organicUSDA Organic*Keurig, K-Cup, and the K logo are trademarks of Keurig Green Mountain, Inc., used with permission. For use with Keurig\\u00ae K-Cup\\u00ae Brewers.","ProductID":1128,"Seller Pincode":700001},{"Sub Category":"Organic","Price":17.99,"Discount":"No Discount","Rating":null,"Title":"Kirkland Signature Organic Raw Honey, 24 oz, 3-count","Feature":"Honey Bear Plastic Jar\\n100% Grade A\\nUSDA Organic\\n72 oz. Total Net Weight","Product Description":"3-count24 oz. Raw Organic Honey100% Grade AProduct of BrazilUSDA OrganicHoney bear plastic jar","ProductID":1124,"Seller Pincode":700001},{"Sub Category":"Meat & Seafood","Price":79.99,"Discount":"No Discount","Rating":"Rated 4.2 out of 5 stars based on 104 reviews.","Title":"Tsar Nicoulai Estate Smoked Sturgeon 6 oz, 6-count, 2.25 lbs","Feature":"Perishable, use or freeze within 21 days of delivery,\\n24 - 72 hrs once opened (refrigerated)   6 oz Estate Smoked Sturgeon, Individually Sealed   2019 Sofi Award Winner, 2017 Good Food Award Winner   Ships Frozen via UPS 2nd Day","Product Description":"We select and handcraft the finest cuts, then cure and triple smoke them for 8-10 hours in small batches using simple ingredients. Our smoked sturgeon is made with only brown sugar, sea salt, and local wood. This artisanal method produces a deliciously firm and mildly smoky fish. At Tsar Nicoulai we produce sustainably raised sturgeon at our aquafarm in Northern California. Our farm is rated Best Choice or Green by the Monterey Bay Aquarium. This product is produced weekly at our farm. We flash freeze the smoked sturge
Steaks, succulent Top Sirloin Steaks, and flavorful Premium Ground beef.   Hand-selected by our Master Graders under our Eating Quality grading system and aged a minimum of 21 days to maximize tenderness and quality.   100% Net Carbon Zero | 100% Grass-Fed Beef | No Added Hormones | No Antibiotics | No Feedlots Ever | Halal   Our Premium Beef Selection contains:\\n2- 10oz Rib-Eye Steaks\\n2- 6oz Tenderloin Steaks\\n2- 10oz New York Strip Steaks\\n2- 8oz Top Sirloin Steaks\\n2- 1lb Premium Ground packs (85% Lean)   What is \\u2018Net Carbon Zero\\u2019?\\n\'Net Carbon Zero\\u2019 means that the total emissions generated by each pound of product, are independently measured and certified, right throughout the whole life of the product.\\nTo achieve and maintain our Net Carbon Zero certification, for every pound of product sold, the equivalent amount of emissions needs to be removed by vegetation occurring on the group of farms that supply these products.","ProductID":1004,"Seller Pincode":302001}]', name='explore_options', id='e20cdf01-21f4-4be8-9724-c01cc7eda1ce', tool_call_id='tooluse_n2lGpGQ0SlG_z7cWkU0dmw')]}
#
# Out:
# PRODUCT RECOMMENDATION NODE:
# state:
# ...

# %%
gen("are you capable of finding distance between two pincodes if two pincodes are provided to you. just yes or no.")

{'messages': [
    HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='f0f6245d-0eb2-4316-85ca-d7c61ce9da15'), 
AIMessage(content="Hello there! Welcome to our grocery shopping assistant. I'm here to help you find and order groceries with ease. \n\nWould you like to:\n1. Browse products by category\n2. Search for specific items\n3. Check out our current deals\n4. Get help with an existing order\n\nWhat can I assist you with today? Feel free to let me know your preferences, and I'll be happy to guide you through our product selection and ordering process.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '78e524f4-2449-4dcf-9df0-873878a99883', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:00:40 GMT', 'content-type': 'application/json', 'content-length': '614', 'connection': 'keep-alive', 'x-amzn-requestid': '78e524f4-2449-4dcf-9df0-873878a99883'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [2638]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-3f14c31a-0e7f-44a3-86cb-ad1c8de33e00-0', usage_metadata={'input_tokens': 1460, 'output_tokens': 99, 'total_tokens': 1559}), 
HumanMessage(content='show me what products do you have', additional_kwargs={}, response_metadata={}, id='20cd61e4-7837-4d2e-8652-ccea413a0b7d'), 
AIMessage(content=[{'type': 'text', 'text': "I'll help you explore our product catalog. I'll use the Product Recommendation Agent to retrieve a list of available products across different categories."}, {'type': 'tool_use', 'name': 'product_recommendation_agent', 'input': {'request': 'Show available product categories and sample products'}, 'id': 'tooluse_l30_fO5uScisDa8PgHQMPw'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '8da0b2eb-9a4b-46cf-83b6-26fc46b50046', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:01:16 GMT', 'content-type': 'application/json', 'content-length': '513', 'connection': 'keep-alive', 'x-amzn-requestid': '8da0b2eb-9a4b-46cf-83b6-26fc46b50046'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [2257]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-9922daee-cf81-45e1-937d-2a73463f38c7-0', tool_calls=[{'name': 'product_recommendation_agent', 'args': {'request': 'Show available product categories and sample products'}, 'id': 'tooluse_l30_fO5uScisDa8PgHQMPw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1569, 'output_tokens': 90, 'total_tokens': 1659}), 
ToolMessage(content='Based on the results, here\'s a summary of our product categories and some sample products:\n\n1. Bakery & Desserts:\n   - Tootie Pie 11" Heavenly Chocolate Pie (₹89.99)\n   - David\'s Cookies Mile High Peanut Butter Cake (₹56.99)\n   - The Cake Bake Shop 2 Tier Special Occasion Cake (₹299.99)\n\n2. Beverages & Water:\n   - Gatorade Zero Thirst Quencher, Variety Pack (₹18.99)\n   - Capri Sun 100% Juice Variety Pack (₹15.99)\n   - Ito En Jasmine Green Tea (₹21.99)\n\n3. Snacks:\n   - Ruffles Potato Chips, Cheddar & Sour Cream (₹49.99)\n   - Nonni\'s Biscotti, Almond Dark Chocolate (₹13.79)\n   - Frito Lay Classic Mix Variety Pack (₹23.99)\n\n4. Organic Products:\n   - Ruta Maya Organic Medium Roast Whole Bean Coffee (₹44.99)\n   - S&W Organic Black Beans (₹9.99)\n   - Newman\'s Own Organics Coffee K-Cup Pods (₹48.99)\n\n5. Meat & Seafood:\n   - Tsar Nicoulai Estate Smoked Sturgeon (₹79.99)\n   - Coastal Seafood Frozen Lobster Tails (₹229.99)\n   - Silver Fern Farms Grass-Fed Steak Box (₹129.99)\n\nWould you like me to dive deeper into any of these categories or help you find something specific? I can provide more details about products, help you filter by price, or explore other categories.', name='product_recommendation_agent', id='3f8caa8f-b8ca-4f90-9080-c1b16c9e0f1a', tool_call_id='tooluse_l30_fO5uScisDa8PgHQMPw'), 
AIMessage(content='These are just a few samples from our extensive product range. We have products across multiple categories like:\n- Pantry & Dry Goods\n- Cleaning Supplies\n- Household Items\n- Coffee & Beverages\n- Fresh Produce\n- Dairy & Eggs\n- And many more!\n\nWhat type of products are you interested in today? I can help you find exactly what you need. Would you like to:\n1. Browse a specific category\n2. Search for a particular type of product\n3. Filter products by price range\n4. See products available in your location\n\nWhat would you prefer?', additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'a239c9a4-340b-44f0-8192-e684a4cae2f8', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:01:35 GMT', 'content-type': 'application/json', 'content-length': '730', 'connection': 'keep-alive', 'x-amzn-requestid': 'a239c9a4-340b-44f0-8192-e684a4cae2f8'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [3863]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-f0f18341-b529-41a0-9974-4af969c13ae7-0', usage_metadata={'input_tokens': 2123, 'output_tokens': 136, 'total_tokens': 2259}), 
HumanMessage(content='are you capable of finding distance between two pincodes if two pincodes are provided to you. just yes or no.', additional_kwargs={}, response_metadata={}, id='25e61d22-f07b-4925-bb26-48200350ccef'), 
AIMessage(content='Yes.\n\nThe Order Processing Agent can calculate distances between pincodes, which is part of determining delivery logistics and charges. Would you like me to demonstrate this capability by checking the distance between two specific pincodes?', additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'e74c0ec9-4424-412f-bd53-4f53ea00ca98', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:12:52 GMT', 'content-type': 'application/json', 'content-length': '538', 'connection': 'keep-alive', 'x-amzn-requestid': 'e74c0ec9-4424-412f-bd53-4f53ea00ca98'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [1733]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, name='supervisor_agent', id='run-e84040ff-b628-4cd9-9cb2-c9875ef8b50d-0', usage_metadata={'input_tokens': 2288, 'output_tokens': 47, 'total_tokens': 2335, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0})]}
# Out:
# {'messages': [HumanMessage(content='Hi', additional_kwargs={}, response_metadata={}, id='f0f6245d-0eb2-4316-85ca-d7c61ce9da15'), AIMessage(content="Hello there! Welcome to our grocery shopping assistant. I'm here to help you find and order groceries with ease. \n\nWould you like to:\n1. Browse products by category\n2. Search for specific items\n3. Check out our current deals\n4. Get help with an existing order\n\nWhat can I assist you with today? Feel free to let me know your preferences, and I'll be happy to guide you through our product selection and ordering process.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '78e524f4-2449-4dcf-9df0-873878a99883', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 08 May 2025 12:00:40 GMT', 'content-type': 'application/json', 'content-length': '614', 'connection': 'keep-alive', 'x-amzn-requestid': '78e524f4-2449-4dcf-9df0-873878a99883'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [2
# ...

# %%
''' 
Conclusion is 
first states of supervisor agents and subagents are different

supervisor agent state get customer message and send it to subagent, so subagent message is a ToolMessage to supervisor

subagent do get all chat history between Customer and Supervisor agent, also for ToolMessage it has it from it's own tool, 
Queries asked to subagents are converted from type AIMessage to HumanMessage

Between 2 AIMessages there is a ToolMessage.
'''

# %%
gen("can have some breakfast items in Pune withing range 200-500")
# Out:
# PRODUCT RECOMMENDATION NODE:
# state:
# ...

# %%
# msg from supervisor to product_recommendation_agent

from langchain_core.messages import HumanMessage, AIMessage, ToolMessage

state_1 = {'messages': [
    HumanMessage(content='show me what products do you have', additional_kwargs={}, response_metadata={}, id='057bf947-c8ff-48ce-9f34-dceec12dde08'), 
    AIMessage(content=[{'type': 'text', 'text': "I'll help you explore our product range. We have products across various subcategories. Let me show you some random products from different subcategories to give you an overview."}, {'type': 'tool_use', 'name': 'product_recommendation_agent_node', 'input': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Meat & Seafood', 'Organic'], 'request': 'Show random products to give customer an overview of our product range'}, 'id': 'tooluse_gXzhUGYeRcOoEW677mDQhw'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '7c34650a-fff5-4dc0-bb14-85fe8b2b499c', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 21 Apr 2025 05:08:24 GMT', 'content-type': 'application/json', 'content-length': '769', 'connection': 'keep-alive', 'x-amzn-requestid': '7c34650a-fff5-4dc0-bb14-85fe8b2b499c'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [3207]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, id='run-35b61b92-23b5-43d6-8084-f21cc51a7ad7-0', tool_calls=[{'name': 'product_recommendation_agent_node', 'args': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Meat & Seafood', 'Organic'], 'request': 'Show random products to give customer an overview of our product range'}, 'id': 'tooluse_gXzhUGYeRcOoEW677mDQhw', 'type': 'tool_call'}], usage_metadata={'input_tokens': 2582, 'output_tokens': 160, 'total_tokens': 2742, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0})], 'is_last_step': False, 'remaining_steps': 23}
# print(state_1['messages'])
# print(state_1['is_last_step'])
# print(state_1['remaining_steps'])
# print(state_1.keys()) ; print()

# print(f"{len(state_1['messages']) = }")
print(f"{state_1['messages'][0]= }")
print(f"{state_1['messages'][0].content }"); print()

print(f"{state_1['messages'][1]= }")
print(f"{state_1["messages"][1].content = }")
print(f"{state_1["messages"][1].content[0] = }")
print(f"{state_1["messages"][1].content[1] = }")
print(f"{state_1["messages"][1].content[1]['id'] = }")
# print(f"{state_1["messages"][1].tool_calls = }")
# print(f"{state_1["messages"][1].tool_calls[0]['args'] = }")
# print(f"{type(state_1["messages"][1].tool_calls[0]['args']) = }")
# print(f"{state_1["messages"][1].content[0]["text"] }"); print()

# print(f"{state_1['messages'][2]= }")
# print(f"{state_1['messages'][2].content = }")
# print(f"{state_1['messages'][2].status = }"); print()

# print(f"{state_1['messages'][3]= }")
# print(f"{state_1["messages"][3].content[0]["text"]}"); print()
# Out:
# state_1['messages'][0]= HumanMessage(content='show me what products do you have', additional_kwargs={}, response_metadata={}, id='057bf947-c8ff-48ce-9f34-dceec12dde08')
# show me what products do you have
#
# ...

# %%
# Response from product rec agent
response = {'messages': [
    
HumanMessage(content='show me what products do you have', additional_kwargs={}, response_metadata={}, id='057bf947-c8ff-48ce-9f34-dceec12dde08'), 
HumanMessage(content="{'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Meat & Seafood', 'Organic'], 'request': 'Show random products to give customer an overview of our product range'}", additional_kwargs={}, response_metadata={}, name='SUPERVISOR', id='run-35b61b92-23b5-43d6-8084-f21cc51a7ad7-0'), 

AIMessage(content=[{'type': 'text', 
                    'text': "I'll help you explore the product range by showing random products from the specified sub-categories."}, 
                    {'type': 'tool_use', 'name': 'explore_options', 'input': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Meat & Seafood', 'Organic']}, 'id': 'tooluse_qLpvgG-qSACoiVd3YBYKWQ'}], 
            additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '871b7e41-ef25-4a41-b615-87a572f4ab8a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 21 Apr 2025 05:08:28 GMT', 'content-type': 'application/json', 'content-length': '591', 'connection': 'keep-alive', 'x-amzn-requestid': '871b7e41-ef25-4a41-b615-87a572f4ab8a'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [1886]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, id='run-21480588-07c4-40d3-ad37-a50f7f48b37a-0', tool_calls=[{'name': 'explore_options', 'args': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Meat & Seafood', 'Organic']}, 'id': 'tooluse_qLpvgG-qSACoiVd3YBYKWQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1958, 'output_tokens': 111, 'total_tokens': 2069, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0}), 

ToolMessage(content='[{"Sub Category":Pincode":0}]', name='explore_options', id='1e467734-d123-42f5-a3a2-1247c4fc2d5c', tool_call_id='tooluse_qLpvgG-qSACoiVd3YBYKWQ'), 

AIMessage(content="Let me summarize the random products from the selected categories:\n\nBakery & Desserts:\n1. David's Cookies Mile High Peanut Butter Cake (₹56.99)\n2. David's Cookies No Sugar Added Cheesecake & Marble Truffle Cake (₹59.99)\n3. Mary Macleod's Gluten Free Shortbread Cookies (₹49.99)\n4. David's Cookies Chocolate Chunk Frozen Cookie Dough (₹54.99)\n5. St Michel Madeleine French Sponge Cake (₹44.99)\n\nBeverages & Water:\n1. Tang Orange Drink Mix (₹9.99)\n2. Vonbee Honey Citron & Ginger Tea (₹34.99)\n3. Pepsi Mini 7.5 fl oz (30-count) (₹16.49)\n4. Sprite Mini 7.5 fl oz (30-count) (₹18.99)\n5. Red Bull Watermelon Energy Drink (₹41.99)\n\nSnacks:\n1. Savanna Orchards Country Club Mix (₹32.99)\n2. Knott's Berry Farm Raspberry Shortbread Cookies (₹12.99)\n3. Hostess Danish with Icing Variety Pack (₹17.99)\n4. Golden Island Pork Snack Bites (₹21.99)\n5. WildRoots Trail Mix (₹13.99)\n\nMeat & Seafood:\n1. Rastelli Market Fresh Jumbo Lump Crab Cakes (₹199.99)\n2. Northwest Fish Alaskan Bairdi Snow Crab Sections (₹299.99)\n3. Trident Seafoods Smoked Sockeye Salmon (₹59.99)\n4. Kansas City Steak Company USDA Choice Combo Pack (₹279.99)\n5. Mila Chicken Xiao Long Bao Soup Dumplings (₹99.99)\n\nOrganic:\n1. S&W Organic Garbanzo Beans (₹10.99)\n2. Ruta Maya Organic Dark Roast Coffee (₹44.99)\n3. Kirkland Signature Organic Blue Agave (₹10.99)\n4. Kirkland Signature Organic Pure Maple Syrup (₹14.99)\n5. Kirkland Signature Organic 100% Juice Variety Pack (₹17.99)\n\nThis selection provides a diverse range of products across different categories, offering something for various tastes and preferences. The products range from sweet treats and snacks to organic items and meat/seafood options.\n\nThat is all from my side.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'aecf0b5e-e9cc-49c7-a828-b2f9cfac1a3f', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Mon, 21 Apr 2025 05:08:43 GMT', 'content-type': 'application/json', 'content-length': '2076', 'connection': 'keep-alive', 'x-amzn-requestid': 'aecf0b5e-e9cc-49c7-a828-b2f9cfac1a3f'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [14938]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, id='run-2cebd31e-4136-4f2b-9c3a-48408fbadf02-0', usage_metadata={'input_tokens': 9042, 'output_tokens': 677, 'total_tokens': 9719, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0})]}

# %%
print(type(response['messages'][-1].content))
response['messages'][-1].content
# Out:
# <class 'str'>
# ...

# %%
ai_msg_1 = "Let me summarize the random products from the selected categories:\n\nBakery & Desserts:\n1. David's Cookies Mile High Peanut Butter Cake (₹56.99)\n2. David's Cookies No Sugar Added Cheesecake & Marble Truffle Cake (₹59.99)\n3. Mary Macleod's Gluten Free Shortbread Cookies (₹49.99)\n4. David's Cookies Chocolate Chunk Frozen Cookie Dough (₹54.99)\n5. St Michel Madeleine French Sponge Cake (₹44.99)\n\nBeverages & Water:\n1. Tang Orange Drink Mix (₹9.99)\n2. Vonbee Honey Citron & Ginger Tea (₹34.99)\n3. Pepsi Mini 7.5 fl oz (30-count) (₹16.49)\n4. Sprite Mini 7.5 fl oz (30-count) (₹18.99)\n5. Red Bull Watermelon Energy Drink (₹41.99)\n\nSnacks:\n1. Savanna Orchards Country Club Mix (₹32.99)\n2. Knott's Berry Farm Raspberry Shortbread Cookies (₹12.99)\n3. Hostess Danish with Icing Variety Pack (₹17.99)\n4. Golden Island Pork Snack Bites (₹21.99)\n5. WildRoots Trail Mix (₹13.99)\n\nMeat & Seafood:\n1. Rastelli Market Fresh Jumbo Lump Crab Cakes (₹199.99)\n2. Northwest Fish Alaskan Bairdi Snow Crab Sections (₹299.99)\n3. Trident Seafoods Smoked Sockeye Salmon (₹59.99)\n4. Kansas City Steak Company USDA Choice Combo Pack (₹279.99)\n5. Mila Chicken Xiao Long Bao Soup Dumplings (₹99.99)\n\nOrganic:\n1. S&W Organic Garbanzo Beans (₹10.99)\n2. Ruta Maya Organic Dark Roast Coffee (₹44.99)\n3. Kirkland Signature Organic Blue Agave (₹10.99)\n4. Kirkland Signature Organic Pure Maple Syrup (₹14.99)\n5. Kirkland Signature Organic 100% Juice Variety Pack (₹17.99)\n\nThis selection provides a diverse range of products across different categories, offering something for various tastes and preferences. The products range from sweet treats and snacks to organic items and meat/seafood options.\n\nThat is all from my side."
print(ai_msg_1); print()
# Out:
# Let me summarize the random products from the selected categories:
#
# Bakery & Desserts:
# 1. David's Cookies Mile High Peanut Butter Cake (₹56.99)
# 2. David's Cookies No Sugar Added Cheesecake & Marble Truffle Cake (₹59.99)
# 3. Mary Macleod's Gluten Free Shortbread Cookies (₹49.99)
# 4. David's Cookies Chocolate Chunk Frozen Cookie Dough (₹54.99)
# 5. St Michel Madeleine French Sponge Cake (₹44.99)
#
# Beverages & Water:
# 1. Tang Orange Drink Mix (₹9.99)
# 2. Vonbee Honey Citron & Ginger Tea (₹34.99)
# 3. Pepsi Mini 7.5 fl oz (30-count) (₹16.49)
# 4. Sprite Mini 7.5 fl oz (30-count) (₹18.99)
# 5. Red Bull Watermelon Energy Drink (₹41.99)
#
# Snacks:
# 1. Savanna Orchards Country Club Mix (₹32.99)
# 2. Knott's Berry Farm Raspberry Shortbread Cookies (₹12.99)
# 3. Hostess Danish with Icing Variety Pack (₹17.99)
# 4. Golden Island Pork Snack Bites (₹21.99)
# 5. WildRoots Trail Mix (₹13.99)
#
# Meat & Seafood:
# 1. Rastelli Market Fresh Jumbo Lump Crab Cakes (₹199.99)
# ...

# %%
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage

state_3 = {'messages': [
    HumanMessage(content='show me some products', additional_kwargs={}, response_metadata={}, id='b145ed06-e78b-49e5-add3-1f663de55a53'), HumanMessage(content="{'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Pantry & Dry Goods'], 'request': 'Show a variety of products to help customer explore our inventory'}", additional_kwargs={}, response_metadata={}, name='SUPERVISOR', id='run-6a602eac-4f69-4e2f-83be-e0e8c734492c-0'), 
    AIMessage(content=[{'type': 'text', 'text': "I'll help you explore some products from the specified categories. I'll use the explore_options tool to retrieve a random selection of products."}, {'type': 'tool_use', 'name': 'explore_options', 'input': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Pantry & Dry Goods']}, 'id': 'tooluse__-tRnRoYSfKBcJKnbKAdyQ'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '3754eef8-7ea0-47f7-bee3-45a82325d7ee', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 17 Apr 2025 09:42:33 GMT', 'content-type': 'application/json', 'content-length': '628', 'connection': 'keep-alive', 'x-amzn-requestid': '3754eef8-7ea0-47f7-bee3-45a82325d7ee'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [2323]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, id='run-4e1687d5-499a-4d5e-b5d8-cc13792ddf79-0', tool_calls=[{'name': 'explore_options', 'args': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Pantry & Dry Goods']}, 'id': 'tooluse__-tRnRoYSfKBcJKnbKAdyQ', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1951, 'output_tokens': 118, 'total_tokens': 2069, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0}), 
    ToolMessage(content='[{"Sub Category":"Bakery & Desserts","Price":56.99,"Discount":"No Discount","Rating":"Rated 4.3 out of 5 stars based on 265 reviews.","Title":"David\\u2019s Cookies Mile High Peanut Butter Cake, 6.8 lbs (14 Servings)", side.', 
                additional_kwargs={}, 
                response_metadata={'ResponseMetadata': {'RequestId': '7219ab59-7543-4a80-8613-2c33ff7f3a0a', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 17 Apr 2025 09:42:44 GMT', 'content-type': 'application/json', 'content-length': '1908', 'connection': 'keep-alive', 'x-amzn-requestid': '7219ab59-7543-4a80-8613-2c33ff7f3a0a'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [10632]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, 
                id='run-797cd8ea-db85-4852-94ef-e77a99ba6cf1-0', 
                usage_metadata={'input_tokens': 6900, 'output_tokens': 563, 'total_tokens': 7463, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0})]}

print(state_3['messages'])
# print(state_3['is_last_step'])
# print(state_3['remaining_steps'])
# print(state_3.keys()) ; print()

print(f"{len(state_3['messages']) = }")
print(f"{state_3['messages'][0]= }")
print(f"{state_3['messages'][0].content }"); print()

print(f"{state_3['messages'][1]= }")
print(f"{state_3["messages"][1].content = }")
# print(f"{state_3["messages"][1].tool_calls = }")
# print(f"{state_3["messages"][1].tool_calls[0]['args'] = }")
# print(f"{type(state_3["messages"][1].tool_calls[0]['args']) = }")
# print(f"{state_3["messages"][1].content[0]["text"] }"); print()
# Out:
# [HumanMessage(content='show me some products', additional_kwargs={}, response_metadata={}, id='b145ed06-e78b-49e5-add3-1f663de55a53'), HumanMessage(content="{'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Pantry & Dry Goods'], 'request': 'Show a variety of products to help customer explore our inventory'}", additional_kwargs={}, response_metadata={}, name='SUPERVISOR', id='run-6a602eac-4f69-4e2f-83be-e0e8c734492c-0'), AIMessage(content=[{'type': 'text', 'text': "I'll help you explore some products from the specified categories. I'll use the explore_options tool to retrieve a random selection of products."}, {'type': 'tool_use', 'name': 'explore_options', 'input': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Pantry & Dry Goods']}, 'id': 'tooluse__-tRnRoYSfKBcJKnbKAdyQ'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': '3754eef8-7ea0-47f7-bee3-45a82325d7ee', 'HTTPStatusCode': 200, 'HTTPHeaders': {'
# ...

# %%
state_2 = {'messages': [HumanMessage(content='show me some products', additional_kwargs={}, response_metadata={}, id='675f002d-1dd3-4214-9880-f3a8b68384e0'), AIMessage(content=[{'type': 'text', 'text': "I'll help you explore some random products from various sub-categories. I'll use the explore_options tool to show you a diverse range of products."}, {'type': 'tool_use', 'name': 'explore_options', 'input': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Organic', 'Meat & Seafood']}, 'id': 'tooluse_7DIETNCcQ16hxqUUCzNrIg'}], additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'c381b7f3-83cd-4d15-a6c3-4b4322cba2ff', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 17 Apr 2025 09:30:29 GMT', 'content-type': 'application/json', 'content-length': '636', 'connection': 'keep-alive', 'x-amzn-requestid': 'c381b7f3-83cd-4d15-a6c3-4b4322cba2ff'}, 'RetryAttempts': 0}, 'stopReason': 'tool_use', 'metrics': {'latencyMs': [2696]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, id='run-2075592c-df49-4a5a-b633-a071e69511cd-0', tool_calls=[{'name': 'explore_options', 'args': {'check_sub_cat_list': ['Bakery & Desserts', 'Beverages & Water', 'Snacks', 'Organic', 'Meat & Seafood']}, 'id': 'tooluse_7DIETNCcQ16hxqUUCzNrIg', 'type': 'tool_call'}], usage_metadata={'input_tokens': 1889, 'output_tokens': 123, 'total_tokens': 2012, 'cache_read_input_tokens': 0, 'cache_write_input_tokens': 0}), ToolMessage(content='[{"Sub Category":"Bakery & Desserts","Price":109.99,"Discount":"No Discount","Rating":"Rated 4.2 out of 5 stars based on 181 reviews.","Title":"Ferrara\'s Bakery 24 Large Cannoli\'s (12 Plain Filled and 12 Hand Dipped Belgian Chocolate)","Feature":"12 Large Plain Filled Cannoli   12 Large Hand Dipped Belgian Chocolate Cannoli   Plain Cannoli: After thawing should be eaten within 2 hours for maximize crispness   Chocolate Cannoli: After thawing should be eaten within 48 hours   Frozen: Can be stored up to a year","Product Description":"Ferrara\'s Bakery of Little Italy in New York City 12 Large Plain Filled Cannoli and 12 Large Hand Dipped Belgian Chocolate CannoliThe Cannoli is a Sicilian pastry. First introduced more than 125 years ago by Cafe\\u2019 Ferrara. A light crispy shell, sweet, velvety, creamy ricotta with chocolate chips & citron. Ferrara dips their traditional crispy cannoli shells by hand in rich Belgian chocolate before filling them with sweet ricotta cream studded with chocolate chipsA little history about the world famous Ferarra bakery. Since 1892 when our great grandfather, Enrico Scoppa and our great grand-uncle, Antonio Ferrara, opera impresario and showman, opened a cafe called Caf\\u00e9 A. Ferrara in Little Italy section in New York City we have prided ourselves on creating superb Italian specialties We take the extra step
not edible, please do not consume, remove before eating)\\nDimensions: 9\\u201d diameter, 7\\u201d high\\nServes 16-22\\nEach Cake Arrives With It\\u2019s Own Cake Care Card\\nAllergens: Contains Wheat, Milk, Soy, Egg\\nShips Frozen","ProductID":2,"Seller Pincode":0},{"Sub Category":"Bakery & Desserts","Price":89.99,"Discount":"No Discount","Rating":"Rated 3 out of 5 stars based on 5 reviews.","Title":"Tootie Pie 11\\" Heavenly Chocolate Pie, 2- pack ","Feature":"Two   11\\" Heavenly Chocolate Pie   1 Pie Serves Approximately 8-10 People   Each Pie is Diameter: 11\\" Each and Weight:   3.5 lbs.   Ships with Dry Ice to Maintain Quality & Freshness   Made in the USA","Product Description":"Only for the truly serious chocolate lover, Tootie\\u2019s Heavenly Chocolate Pie is a gooey, fudgy, decadent slice of heaven! With layers of rich, chocolatey filling, surrounded by our handcrafted, flaky crust, it\\u2019s truly a small slice of heaven.\\nSome of our products may contain nuts. Our facility is NOT a nut-free facility, and as a result it is possible that any product may have come in contact with nut or nut oils.\\nImportant Handling Instructions:\\nIf not being consumed immediately upon arrival, your pie should be placed in the freezer. The pie will arrive at least partially frozen and can be refrozen in its original packaging for up to 6 months or stored in a refrigerator for up to 7 days. The pie is fully baked and can be enjoyed chilled or at room temperature. Thaw the pie in the fridge for about 4 hours (or on your kitchen counter for around 2 hours).","ProductID":31,"Seller Pincode":0},{"Sub Category":"Bakery & Desserts","Price":59.99,"Discount":"No Discount","Rating":"Rated 4.4 out of 5 stars based on 232 reviews.","Title":"David\'s Cookies No Sugar Added Cheesecake & Marble Truffle Cake, 2-pack (28 Slices Total)","Feature":"2-count\\nNo Sugar Added\\nKosher OU-Dairy","Product Description":"Creamy Dreamy:This smooth creamy cheesecake has no sugar added and no flour. It\\u2019s hard to believe we\\u2019ve taken that out, and what remains is a light luscious dessert with no unpleasant aftertaste.Marble Truffle:A layer of our rich, delicious, flourless, no-sugar-added (NSA) chocolate truffle cake is topped with a layer of our wonderful no-sugar-added cheesecake, then swirled with a bit of chocolate on top. The combination results in a flourless cake that is the perfect blend of rich sinful chocolate balanced with cool creamy cheesecake. Perfect for chocolate lovers as well as cheesecake lovers.Includes:1 - Creamy Dreamy Cheesecake 1- Marble Truffle CheesecakeEach Cheesecake serves approximately 14 people28 slices totalWeight: Approximately 3 lbs. 5 oz. EachShips in Cooler with Dry Ice to Maintain Quality & FreshnessMade in the USAKosher OU-DairySome of our products may contain nuts. Our facility is NOT a nut-free facility, and as a result it is possible that any product may have come in contact with nut or nut oilsImportant Handling Instructions: If not being consumed immediately upon arrival, cakes should be placed in freezer. Allow two hours for cakes to thaw prior to serving. The dessert will arrive at least partially frozen and can be refrozen in its original packaging for up to 6 months or stored in a refrigerator for at least 2 to 3 days.","ProductID":8,"Seller Pincode":0},{"Sub Category":"Beverages & Water","Price":49.99,"Discount":"No Discount","Rating":null,"Title":"5-hour Energy Shot, Extra Strength, Grape, 1.93 fl. oz, 24-count","Feature":"Extra Strength Energy Shot\\nGrape Flavor\\nSugar Free\\n1.93 fl oz Bottle\\n24 Count","Product Description":"Extra Strength Energy ShotGrape FlavorSugar free1.93 fl oz Bottle24 Count","ProductID":163,"Seller Pincode":0},{"Sub Category":"Beverages & Water","Price":18.99,"Discount":"No Discount","Rating":null,"Title":"Tropicana, Apple Juice, 15.2 fl oz, 12-Count","Feature":"100% Juice   100% Daily Value of Vitamin C   From Concentrate with Other Natural Flavors and Ingredients   Marked for Resale   12-Count","Product Description":"Apple Juice\\n15.2 fl oz bottle","ProductID":51,"Seller Pincode":0},{"Sub Category":"Beverages & Water","Price":19.99,"Discount":"After $5 OFF","Rating":null,"Title":"Poppi Prebiotic Soda, Variety Pack, 12 fl oz, 15-count","Feature":"5 - Strawberry Lemon   5 - Orange   5 - Cherry Limeade   12 fl oz Cans   15 Total Cans","Product Description":"Prebiotics for a healthy gut\\n5g sugar or less\\nImmunity sidekick","ProductID":39,"Seller Pincode":0},{"Sub Category":"Beverages & Water","Price":25.99,"Discount":"No Discount","Rating":null,"Title":"C2O Coconut Water Hydration Pack, The Original, 17.5 fl oz, 15-count","Feature":"Never From Concentrate   Plant Based Hydration   Electrolytes in Every Can   Non-GMO   Chill before serving","Product Description":"Coconut Water Hydration PackThe Original17.5 fl oz (518 mL) can15-countMore Information:Non-GMOChill before serving","ProductID":92,"Seller Pincode":0},{"Sub Category":"Beverages & Water","Price":14.99,"Discount":"No Discount","Rating":null,"Title":"Kirkland Signature Green Tea Bags, 1.5 g, 100-count","Feature":"100-count   1.5 g. bags   A Blend of Sencha & Matcha   Hot & Cold Brewing   Product of Japan","Product Description":"100-count1.5 g. bags150 g. Total net weightProduct of Japan","ProductID":63,"Seller Pincode":0},{"Sub Category":"Snacks","Price":9.49,"Discount":"No Discount","Rating":null,"Title":"Nilla Wafers Cookies, 15 oz, 2 Count","Feature":"Vanilla Cookies   2 Stay Fresh Packs   Trans Fat 0g per serving   Kosher Dairy   Net Weight: 30 oz.","Product Description":"Nilla Wafers\\n2-count\\n15 oz. pack","ProductID":1620,"Seller Pincode":110025},{"Sub Category":"Snacks","Price":17.99,"Discount":"No Discount","Rating":null,"Title":"Power Crunch Protein Energy Bar, French Vanilla, 1.4 oz, 12-count","Feature":"14 grams of Protein   5 grams of Sugar   French Vanilla Creme   Made in Canada","Product Description":"12-count1.4 oz","ProductID":1530,"Seller Pincode":110025},{"Sub Category":"Snacks","Price":11.49,"Discount":"No Discount","Rating":null,"Title":"Blue Diamond Almonds, Smokehouse, 1.5 oz, 12-count","Feature":"Smokehouse Almonds   12-count   1.5 oz tube   18 oz. Total Net Weight","Product Description":"Smart Snacking","ProductID":1634,"Seller Pincode":400050},{"Sub Category":"Snacks","Price":23.99,"Discount":"No Discount","Rating":null,"Title":"Kind Bar, Variety Pack, 1.4 oz, 20-count","Feature":"Kosher   Gluten-Free   No Genetically Engineered Ingredients   5g Sugar   5g Protein","Product Description":"50% Less Sugar Per Bar Than The Average Nutrition Bar (12g Sugar)Ingredients You Can See & Pronounce10 Salted Caramel & Dark Chocolate Almond10 Dark Chocolate Almond & Sea Salt20-count1.4 oz barsTotal Net Weight: 28 oz","ProductID":1610,"Seller Pincode":400050},{"Sub Category":"Snacks","Price":32.99,"Discount":"No Discount","Rating":"Rated 4.5 out of 5 stars based on 786 reviews.","Title":"Made in Nature USDA Organic Dates 40 oz, 2-pack","Feature":"40 oz 2-pack\\nUSDA Certified Organic\\nNon-GMO Project Verified\\nNut Allergen Free","Product Description":"USDA certified organic2 Bags, 40 oz. eachTotal 80 oz.No synthetic pesticides or herbicidesUnsulfured fruitsNo sugar addedNo artificial colors, flavors or additivesNon-GMO Project VerifiedNut allergen freeGluten freeVeganKosherHalal","ProductID":1670,"Seller Pincode":400050},{"Sub Category":"Organic","Price":10.99,"Discount":"No Discount","Rating":null,"Title":"Kirkland Signature, Organic Tomato Paste, 6 oz, 12-Count","Feature":"USDA Certified Organic   Vine Ripened   California Roma Tomatoes   Freshly Packed   Net Weight 72 oz.","Product Description":"12-count\\n6 oz. cans\\nPacked in the USA","ProductID":1148,"Seller Pincode":0},{"Sub Category":"Organic","Price":14.99,"Discount":"No Discount","Rating":null,"Title":"Thai Kitchen Organic Coconut Milk, Unsweetened, 13.66 fl oz, 6-count","Feature":"USDA Organic   Gluten Free   Dairy Free   Non-GMO   Vegan","Product Description":"6-count13.66 fl. oz. cans81.96 fl. oz. Total net weightProduct of ThailandUnsweetened","ProductID":1129,"Seller Pincode":0},{"Sub Category":"Organic","Price":9.99,"Discount":"No Discount","Rating":null,"Title":"Kirkland Signature Organic No-Salt Seasoning, 14.5 oz","Feature":"Kosher(Circle U)   USDA Organic   A Blend of 21 Organic Spices   Packed in USA   Net Weight 14.5 oz.","Product Description":"No-Salt Seasoning\\nGives great flavor to steaks, burgers, ribs, chicken and turkey\\nStore away from direct sunlight\\nStore in cool, dry area","ProductID":1120,"Seller Pincode":0},{"Sub Category":"Organic","Price":18.99,"Discount":"No Discount","Rating":null,"Title":"Kirkland Signature, Organic Extra Virgin Olive Oil, 2 L","Feature":"Organic Extra Virgin Olive Oil   2 Liter Plastic Bottle   First Cold Pressed   USDA Organic   Kosher","Product Description":"Displays a full-bodied elegant aroma with a distinctive, rich taste","ProductID":1119,"Seller Pincode":0},{"Sub Category":"Organic","Price":44.99,"Discount":"No Discount","Rating":"Rated 4.8 out of 5 stars based on 2216 reviews.","Title":"Ruta Maya Organic Dark Roast Coffee, 5 lbs","Feature":"5 lbs of Organic Whole Bean Coffee   Dark Roast","Product Description":"Rich, distinctive and aromatic roast. Smooth flavor with a balanced aftertaste. Shade-grown 100% Arabica beans, certified USDA organic by the Texas Department of Agriculture. Cultivated by a cooperative of Maya Indian farmers in the Highlands of Chiapas, Mexico.Features:5 lb bagDark RoastCertified Organic Whole bean 100% Arabica, shade grown beansFrom the Highlands of Chiapas, Mexico","ProductID":1144,"Seller Pincode":0},{"Sub Category":"Meat & Seafood","Price":64.99,"Discount":"No Discount","Rating":"Rated 5 out of 5 stars based on 6 reviews.","Title":"Sampler: Dry-
"Please Check Below for Pack Contents   Wild & Sustainably Caught   FedEx 2-day Shipping   Flash Frozen to Preserve Quality & Freshness","Product Description":"Semi-dehydrated then frozen Sea Cucumber Skins graded #1; 5 lbs of Skin (2 bags @ 2.5 lb each)\\nFrozen Cucumber meat graded #1; 2 lbs of meat\\nWild & sustainably caught\\nFedEx 2-day Shipping\\nFlash Frozen to preserve Quality & Freshness\\nCaught by independent fishermen & their families   We have sought out from afar the Alaskan Giant Red Sea Cucumbers to offer you the convenience top quality Sea cucumber shipped to your door. Our Alaskan Sea cucumbers are hand-picked by local divers off the sea floor and are delivered directly to our dock live for further preparation. These Sea Cucumber have been prepared for you by separating the meat from the skins and freezing separately. Receive 5 lbs Wild Alaskan Sea Cucumber skins that are semi-dehydrated by cooking, salted, and then individually flash frozen and 1 bag (2 lbs) of frozen Wild Alaskan Sea Cucumber meat. Each box includes the very best quality, only containing #1 grade meat and skins.\\nNOTE ABOUT FROZEN: Once seafood leaves the water, freshness and quality can only be maintained by freezing. Flash freezing halts the natural deterioration of the flesh, and locks in freshness. By purchasing frozen seafood rather than thawed, you are maintaining the quality and freshness until the moment you are ready to enjoy it. Thaw seafood in the refrigerator, and once thawed, it will keep for up to seven days.","ProductID":975,"Seller Pincode":0}]', name='explore_options', id='1f291464-5d49-4d5a-ba67-d52a876ffc16', tool_call_id='tooluse_7DIETNCcQ16hxqUUCzNrIg'), AIMessage(content="I've retrieved a diverse selection of products from different sub-categories. Let me highlight a few interesting items:\n\n1. Bakery & Desserts:\n- Ferrara's Bakery Cannoli (24 Large Cannolis): ₹109.99\n  - 12 Plain Filled and 12 Hand Dipped Belgian Chocolate Cannolis\n  - Rated 4.2/5 from 181 reviews\n\n2. Beverages:\n- 5-hour Energy Shot (Extra Strength, Grape): ₹49.99\n  - 24-count pack\n  - Sugar-free energy shot\n\n3. Snacks:\n- Kind Bar Variety Pack: ₹23.99\n  - 20-count (10 Salted Caramel & Dark Chocolate Almond, 10 Dark Chocolate Almond & Sea Salt)\n  - Gluten-free, 5g sugar, 5g protein\n\n4. Organic Products:\n- Ruta Maya Organic Dark Roast Coffee: ₹44.99\n  - 5 lbs of whole bean coffee\n  - Shade-grown 100% Arabica beans\n  - Rated 4.8/5 from 2,216 reviews\n\n5. Meat & Seafood:\n- Rastelli Antibiotic-Free Wagyu Beef Craft Burgers: ₹109.99\n  - 24 burgers (5.5 oz each)\n  - Antibiotic-free, no added steroids or hormones\n  - Rated 4.5/5 from 196 reviews\n\nWould you like me to provide more details about any of these products or explore a specific category in more depth? That is all from my side.", additional_kwargs={}, response_metadata={'ResponseMetadata': {'RequestId': 'e4ccecd4-34d2-4234-b735-72e4358e42cc', 'HTTPStatusCode': 200, 'HTTPHeaders': {'date': 'Thu, 17 Apr 2025 09:30:39 GMT', 'content-type': 'application/json', 'content-length': '1318', 'connection': 'keep-alive', 'x-amzn-requestid': 'e4ccecd4-34d2-4234-b735-72e4358e42cc'}, 'RetryAttempts': 0}, 'stopReason': 'end_turn', 'metrics': {'latencyMs': [9039]}, 'model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0'}, id='run-0e85003c-98d0-43b4-a673-8f2b89d333b1-0', usage_metadata={'input_tokens': 9167, 'output_tokens': 415, 'total_tokens': 9582})]}

print(f"{len(state_2['messages']) = }")
print(f"{state_2['messages'][0] = }")
print(f"{state_2['messages'][1] = }")
print(f"{state_2['messages'][1].content = }")
print(f"{state_2['messages'][1].id = }")
print(f"{state_2['messages'][1].tool_calls = }")
# print(f"{state_2['messages'][2] = }")
# print(f"{state_2['messages'][3] = }")
# Out:
# len(state_2['messages']) = 4
# state_2['messages'][0] = HumanMessage(content='show me some products', additional_kwargs={}, response_metadata={}, id='675f002d-1dd3-4214-9880-f3a8b68384e0')
# ...

# %%
from supervisor_agent_4 import supervisor_agent

config = {"configurable": {"thread_id": "aip232"}}
# r1 = supervisor_agent.invoke({'messages':"Hi"},config = config)
# r1

def gen_3(prompt):
    for repsonse_tupple in supervisor_agent.stream({'messages': prompt}, 
                                            config= config, 
                                            stream_mode="messages",):
        print(repsonse_tupple);print()

# gen_3("Hi")

# %%
# gen_3("can I have some breakfast items in Pune withing range 200-500")

# %%
config = {"configurable": {"thread_id": "vir232"}}
from langchain_core.messages import HumanMessage, AIMessage, ToolMessage, AIMessageChunk

def graph_response_generator(prompt):
    user_msg = {"messages":[{"role": "human", "content" : prompt}]}

    ToolMessage_passed_Flag = False
    Tool_use_Found = False
    
    for response_tuple, metadata in supervisor_agent.stream(user_msg, 
                                                        config= config, 
                                                        stream_mode="messages"):

        if isinstance(response_tuple.content, list) and len(response_tuple.content) > 0:
            if response_tuple.content[0].get("type") == "tool_use":
                Tool_use_Found = True 

            elif not Tool_use_Found and response_tuple.content[0].get("type") == "text":
                # Text_use_Found = True 
                print("When tool use not found")
                print(f'{response_tuple= }  {metadata= }'); print()
                # yield response_tuple.content[0].get("text","")
           

        if Tool_use_Found:
            if type(response_tuple) == ToolMessage and response_tuple.status == "success":
                ToolMessage_passed_Flag = True 
                print("Point where tool use found")
                print(f'{response_tuple= }  {metadata= }'); print()

            if ToolMessage_passed_Flag and type(response_tuple) == AIMessageChunk and isinstance(response_tuple.content, list) and len(response_tuple.content) > 0:
                print("Found success TOOL USE")
                print(f'{response_tuple= }  {metadata= }'); print()
                # yield response_tuple.content[0].get("text","")

graph_response_generator("i'd like to have 2 pack 160, 2 pack of 43 and 1 pack of 20, give me details of these products first")
# Out:
# When tool use not found
# response_tuple= AIMessageChunk(content=[{'type': 'text', 'text': 'I', 'index': 0}], additional_kwargs={}, response_metadata={}, id='run-0a80acf6-95c4-42d4-9a96-5505bbbf2f7a')  metadata= {'thread_id': 'vir232', 'langgraph_step': 1, 'langgraph_node': 'agent', 'langgraph_triggers': ('branch:to:agent',), 'langgraph_path': ('__pregel_pull', 'agent'), 'langgraph_checkpoint_ns': 'agent:34bfb422-d8a8-0c7e-395c-1fc340f33de0', 'checkpoint_ns': 'agent:34bfb422-d8a8-0c7e-395c-1fc340f33de0', 'ls_provider': 'amazon_bedrock', 'ls_model_name': 'us.anthropic.claude-3-5-haiku-20241022-v1:0', 'ls_model_type': 'chat', 'ls_temperature': 0.0}
#
# When tool use not found
# ...

# %%
from supervisor_agent_4 import supervisor_agent

from IPython.display import display, Image
display(Image(supervisor_agent.get_graph().draw_mermaid_png()))
